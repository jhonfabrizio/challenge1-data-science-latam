# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


t = pd.read_csv('/content/tiendas.csv')

nft1 = nft2 = nft3 = nft4 = 0
ft1 =  ft2 = ft3 = ft4 = 0
cct1 = cct2 = cct3 = cct4 = 0
cet1 = cet2 = cet3 = cet4 = 0

for row in t.itertuples():
    if (row.Tienda == 1):

        # nft   Numero de filas de la tienda
        # ft    Facturacion de tienda
        # cct1  Suma calificacion de los clientes
        # ce    Suma del costo del envio

        nft1 = nft1 + 1
        ft1 = ft1 + row.Precio
        cct1 = cct1 + row.Calificacion
        cet1 = cet1 + row.CostoDeEnvio

    if (row.Tienda == 2):

        nft2 = nft2 + 1
        ft2 = ft2 + row.Precio
        cct2 = cct2 + row.Calificacion
        cet2 = cet2 + row.CostoDeEnvio

    if (row.Tienda == 3):

        nft3 = nft3 + 1
        ft3 = ft3 + row.Precio
        cct3 = cct3 + row.Calificacion
        cet3 = cet3 + row.CostoDeEnvio

    if (row.Tienda == 4):

        nft4 = nft4 + 1
        ft4 = ft4 + row.Precio
        cct4 = cct4 + row.Calificacion
        cet4 = cet4 + row.CostoDeEnvio

# print("T = Tienda")
print('Numero de filas por tienda')
filas = {"T1":nft1,"T2":nft2,"T3":nft3,"T4":nft4}
print(filas)
print()

print("Facturacion total")
facturacion = {"T1":round(ft1,2),"T2":round(ft2,2),"T3":round(ft3,2),"T4":round(ft4,2)}
print(facturacion)
print()

tiendas_nombres = list(facturacion.keys())
facturacion_valores = list(facturacion.values())
plt.figure(figsize=(10, 6))
plt.plot(tiendas_nombres, facturacion_valores, marker='o', label='Serie 1', color='blue')

plt.title('Facturacion total', fontsize=14, fontweight='bold')
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Ventas', fontsize=12)
plt.legend()

print()

print("Facturacion promedio de cada tienda")
facturacion_promedio = {"T1":round(ft1/nft1,2),"T2":round(ft2/nft2,2),"T3":round(ft3/nft3,2),"T4":round(ft4/nft4,2)}
print(facturacion_promedio)
print()

tiendas_nombres = list(facturacion.keys())
facturacion_valores = list(facturacion_promedio.values())
plt.figure(figsize=(10, 6))

plt.plot(tiendas_nombres, facturacion_valores, marker='o', label='Serie 1', color='red')

plt.title('Facturacion promedio', fontsize=14, fontweight='bold')
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Ventas', fontsize=12)
plt.legend()
















print()

#sorted_facturacion = dict(sorted(facturacion.items(), key=lambda item: item[1], reverse=True))
#print(sorted_facturacion)
#sorted_calificacion = dict(sorted(calificacion.items(), key=lambda item: item[1], reverse=True))
#print(sorted_calificacion)
#sorted_costoDeEnvio = dict(sorted(costoDeEnvio.items(), key=lambda item: item[1], reverse=True))
#print(sorted_costoDeEnvio)
# Out:
# Numero de filas por tienda
# {'T1': 2359, 'T2': 2359, 'T3': 2359, 'T4': 2358}
#
# Facturacion total
# {'T1': 1150880400, 'T2': 1116343500, 'T3': 1098019600, 'T4': 1038375700}
#
#
# Facturacion promedio de cada tienda
# {'T1': 487867.91, 'T2': 473227.43, 'T3': 465459.77, 'T4': 440362.89}

# %% [markdown]
# # 2. Ventas por categoría

# %%
import seaborn as sns

ventas_totales = t.groupby(['Tienda', 'CategoriaDelProducto'])['Precio'].sum().reset_index()
print(ventas_totales)
print()
print()

ventas_pivot = ventas_totales.pivot(index='Tienda', columns='CategoriaDelProducto', values='Precio')
print(ventas_pivot.fillna(0).to_string())

#ventas_pivot = ventas_totales.pivot(index='Tienda', columns='CategoriaDelProducto', values='Precio').fillna(0)
#print(ventas_pivot)

plt.figure(figsize=(10, 6))
sns.barplot(data=ventas_totales, x='Tienda', y='Precio', hue='CategoriaDelProducto')
plt.title('Ventas totales por Tienda y Categoría')
plt.ylabel('Ventas totales')
plt.xlabel('Tienda')
plt.legend(title='Categoría', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
#     Tienda     CategoriaDelProducto     Precio
# 0        1  Artículos para el hogar   12698400
# 1        1     Deportes y diversión   39290000
# 2        1        Electrodomésticos  363685200
# 3        1             Electrónicos  429493500
# 4        1   Instrumentos musicales   91299000
# 5        1                 Juguetes   17995700
# 6        1                   Libros    8784900
# 7        1                  Muebles  187633700
# 8        2  Artículos para el hogar   14746900
# 9        2     Deportes y diversión   34744500
# 10       2        Electrodomésticos  348567800
# 11       2             Electrónicos  410831100
# 12       2   Instrumentos musicales  104990300
# 13       2                 Juguetes   15945400
# 14       2                   Libros   10091200
# 15       2                  Muebles  176426300
# 16       3  Artículos para el hogar   15060000
# 17       3     Deportes y diversión   35593100
# 18       3        Electrodomésticos  329237900
# 19       3             Electrónicos  410775800
# 20       3   Instrumentos musicales   77380900
# 21       3                 Juguetes   19401100
# 22       3                   Libros    9498700
# 23       3                  Muebles  201072100
# 24       4  Artículos para el hogar   15074500
# 25       4     Deportes y diversión   33350100
# 26       4        Electrodomésticos  283260200
# 27       4             Electrónicos  409476100
# 28       4   Instrumentos musicales   75102400
# 29       4                 Juguetes   20262200
# 30       4                   Libros    9321300
# 31       4                  Muebles  192528900
#
#
# CategoriaDelProducto  Artículos para el hogar  Deportes y diversión  Electrodomésticos  Electrónicos  Instrumentos musicales  Juguetes    Libros    Muebles
# Tienda
# 1                                    12698400              39290000          363685200     429493500                91299000  17995700   8784900  187633700
# 2                                    14746900              34744500          348567800     410831100               104990300  15945400  10091200  176426300
# 3                                    15060000              35593100          329237900     410775800                77380900  19401100   9498700  201072100
# 4                                    15074500              33350100          283260200     409476100                75102400  20262200   9321300  192528900

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
print("Calificacion")
calificacion = {"T1":round(cct1/nft1,2),"T2":round(cct2/nft2,2),"T3":round(cct3/nft3,2),"T4":round(cct4/nft4,2)}
print(calificacion)
print()


tiendas_nombres = list(facturacion.keys())
calificacion_valores = list(calificacion.values())
plt.figure(figsize=(10, 6))

plt.plot(tiendas_nombres, calificacion_valores, marker='o', label='Serie 1', color='green')

plt.title('Calificacion promedio', fontsize=14, fontweight='bold')
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Calificacion', fontsize=12)
plt.legend()
# Out:
# Calificacion
# {'T1': 3.98, 'T2': 4.04, 'T3': 4.05, 'T4': 4.0}

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# 1. Contar frecuencia de productos por tienda
frecuencia = t.groupby(['Tienda', 'Producto']).size().reset_index(name='Frecuencia')

# 2. Encontrar producto con mayor frecuencia por tienda
mayor_frecuencia = frecuencia.loc[frecuencia.groupby('Tienda')['Frecuencia'].idxmax()]

# 3. Encontrar producto con menor frecuencia por tienda
menor_frecuencia = frecuencia.loc[frecuencia.groupby('Tienda')['Frecuencia'].idxmin()]

# Mostrar resultados
print("Frecuencia de productos por tienda:")
print(frecuencia)
print("\nProductos con mayor frecuencia por tienda:")
print(mayor_frecuencia)
print("\nProductos con menor frecuencia por tienda:")
print(menor_frecuencia)
# Out:
# Frecuencia de productos por tienda:
#      Tienda                   Producto  Frecuencia
# 0         1          Ajedrez de madera          49
# 1         1                    Armario          60
# 2         1          Asistente virtual          40
# 3         1                Auriculares          50
# 4         1  Auriculares con micrófono          33
# ..      ...                        ...         ...
# 199       4                 Smartwatch          39
# 200       4            Sofá reclinable          47
# 201       4              TV LED UHD 4K          40
# 202       4                Tablet ABXY          45
# 203       4               Vaso térmico          48
#
# [204 rows x 3 columns]
#
# Productos con mayor frecuencia por tienda:
#      Tienda                   Producto  Frecuencia
# 1         1                    Armario          60
# 75        2  Iniciando en programación          65
# 129       3              Kit de bancas          57
# 163       4                   Cama box          62
#
# Productos con menor frecuencia por tienda:
#      Tienda                   Producto  Frecuencia
# 4         1  Auriculares con micrófono          33
# 77        2              Juego de mesa          32
# 111       3    Bloques de construcción          35
# 175       4         Guitarra eléctrica          33

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
print("Costo de envio")
costoDeEnvio = {"T1":round(cet1/nft1,2),"T2":round(cet2/nft2,2),"T3":round(cet3/nft3,2),"T4":round(cet4/nft4,2)}
print(costoDeEnvio)
print()

tiendas_nombres = list(facturacion.keys())
costoDeEnvio_valores = list(calificacion.values())
plt.figure(figsize=(10, 6))

plt.plot(tiendas_nombres, costoDeEnvio_valores, marker='o', label='Serie 1', color='yellow')

plt.title('Calificacion promedio', fontsize=14, fontweight='bold')
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Costo de envio', fontsize=12)
plt.legend()
# Out:
# Costo de envio
# {'T1': 26018.61, 'T2': 25216.24, 'T3': 24805.68, 'T4': 23459.46}

# %%
print("Margen.  Diferencia entre el precio promedio y el gasto por envio")
margen = {"T1":round((ft1/nft1 - cet1/nft1),2),"T2":round((ft2/nft2 - cet2/nft2),2),"T3":round((ft3/nft3 - cet3/nft3),2),"T4":round((ft4/nft4 - cet4/nft4),2)}
print(margen)
print()

titulos = {"T1":"T1", "T2":"T2","T3":"T3","T4":"T4"}
# Obtener las claves (asumiendo que todos tienen las mismas claves)
keys = list(facturacion.keys())
#print(titulos)



# Crea lista de diccionarios
#print("Diccionarios")
diccionarios = [titulos,facturacion_promedio, costoDeEnvio, margen, calificacion]
#print(diccionarios)


# Crear matriz donde cada columna son los valores de un diccionario
matriz = np.array([[d[k] for k in keys] for d in diccionarios]).T

print("Matriz resultante:")
print()
print("-------------------------------------------------------")
print("Tienda Facturacion Envio        Margen   Calificacion")
print("  No.  Promedio(A) Promedio(B)   (A-B)   Promedio")
print("-------------------------------------------------------")
print(matriz)
print("-------------------------------------------------------")
print()
margen_columna = [fila[3] for fila in matriz]

# Encontrar el valor mínimo de la cuarta columna
valor_minimo = min(margen_columna)
print("Valor minimo en la columna Margen: ", valor_minimo)
print("Pienso que la tienda que puede vender es la 4, presenta menor facturacion, aunque tiene una aceptacion del 4 en una escala de 5.")
# Out:
# Margen.  Diferencia entre el precio promedio y el gasto por envio
# {'T1': 461849.3, 'T2': 448011.19, 'T3': 440654.09, 'T4': 416903.44}
#
# Matriz resultante:
#
# -------------------------------------------------------
# Tienda Facturacion Envio        Margen   Calificacion
#   No.  Promedio(A) Promedio(B)   (A-B)   Promedio
# -------------------------------------------------------
# [['T1' '487867.91' '26018.61' '461849.3' '3.98']
#  ['T2' '473227.43' '25216.24' '448011.19' '4.04']
#  ['T3' '465459.77' '24805.68' '440654.09' '4.05']
#  ['T4' '440362.89' '23459.46' '416903.44' '4.0']]
# -------------------------------------------------------
#
# Valor minimo en la columna Margen:  416903.44
# Pienso que la tienda que puede vender es la 4, presenta menor facturacion, aunque tiene una aceptacion del 4 en una escala de 5.
